# %%
import os
import PIL
from PIL import Image
import csv

# %%
# Count the BSE_JSRT files
images = list(set(os.listdir("Dataset/BSE_JSRT")))
# print(images)
res = []

for image in images:
    # loading the image
    img = PIL.Image.open("Dataset/BSE_JSRT/"+image)      
    # fetching the dimensions
    wid, hgt = img.size
    res.append(str(wid) + "x" + str(hgt))
    # displaying the dimensions
    # print(str(wid) + "x" + str(hgt))
print(list(set(res)))
# Out:
# ['2048x2048']

# %%
# with open("BSE_JSRT.csv", "w") as f:
#     csv_writer = csv.writer(f, delimiter=".")
#     csv_writer.writerow(["Images"])
#     for image in images:
#         csv_writer.writerow([image])

# %%
import pandas as pd

# %%
df_bse_jsrt = pd.read_csv("Dataset/BSE_JSRT.csv")
df_jsrt = pd.read_csv("Dataset/JSRT.csv")

# %%
bse_images = df_bse_jsrt.iloc[:,0].tolist()

# %%
len(bse_images)
# Out:
# 241

# %%
jsrt_images = df_jsrt.iloc[:,0].tolist()

# %%
len(jsrt_images)
# Out:
# 241

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
path_image = "Dataset/JSRT/JPCLN003.png"

# %%
img = np.fromfile(path_image,dtype=">i2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-f0096ecdb281> in <module>
# ----> 1 img = np.fromfile(path_image,dtype=">i2").reshape((2048,2048))
#
# ValueError: cannot reshape array of size 643282 into shape (2048,2048)

# %%
img
# Out:
# array([-30384,  20039,   3338, ...,  20036, -20926,  24706], dtype=int16)

# %%
img = Image.open(path_image).convert("L")

# %%
img2 = np.array(img)

# %%
Image.fromarray(np.array(img))
# Out:
# <PIL.Image.Image image mode=L size=2048x2048 at 0x7FD321C8D048>

# %%
np_img = np.array(img)

# %%
mask = (np_img != 255)

# %%
mask
# Out:
# array([[False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
# now add median
img2 = mask*np_img

# %%
med = np.median(img2)
img3 = np.invert(mask)*med + img2

# %%
plt.imshow(img3,cmap="gray")

# %%
plt.imshow(np_img, cmap='gray')
